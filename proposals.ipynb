# %% [markdown]
# To use this script:
# 1. Save the requirements tab in a spreadsheet as a UTF-8 CSV (note: not a normal CSV; must specify UTF-8)
# 2. When calling ingestRFP, indicate start_row = the number of the row where the requirements start
# 3. end_row = the last row to read in
# 4. req_i = the index (number) of the column with the requirements
# 5. rat_i = the index (number) of the column with the ratings we specify
# 6. resp_i = the index (number) of the column with the responses we specify
# 7. Note that the column header gets overwritten for the requirement, rating, and response columns. These should be changed back.
# 8. The script adds a column called "match" which tells you how strong of a match the requirement was to a past requirement. A value of 1.00 means it was an exact match. The answers get very unreliable when the match is less than 0.9, so read those extra-carefully.

# %%
# read in CSVs of requirements, ratings, and responses as a dataframe
# Cobb-specific
import numpy as np
import pandas as pd

def ingestRFP(file, start_row = 0, end_row = 999, req_i = 2, rat_i = 5, resp_i =6):
    '''
    filelist is a file path to a CSV for a proposal
    req_i is the column index for requirements
    resp_i is the column index for responses
    start_row is the row to start reading on
    end_row is the row to stop reading on
    outputs a dataframe of requirement-response pairs
    
    '''
    
    # NOTE: in Excel, save as CSV UTF-8
    rfp_df = pd.read_table(file, 
                           sep = ",", 
                           skiprows = (start_row-1), 
                           nrows = (end_row - start_row), 
                           skipinitialspace = True)

    # df.rename(columns={ df.columns[1]: "whatever" })
    
    # rename the columns to standardize
    rfp_df = rfp_df.rename(columns = {
        rfp_df.columns[req_i]: 'req',
        rfp_df.columns[rat_i]: 'rating',
        rfp_df.columns[resp_i]: 'resp',
    })

    return rfp_df

corpus = ingestRFP('C:/Users/ahicken/Documents/proposal_data/naedutf8.csv', 8, 230, 2, 6, 7)
# last row should be 230

newRFP = ingestRFP('C:/Users/ahicken/Documents/proposal_data/adha.csv', 8, 132, 2, 5, 6)
# last row should be 132

newRFP
# Out:
#      Item                           Functional Area  \
# 0       2                       Educational Content
# 1       3                       Educational Content
# 2       4                       Educational Content
# 3       7                       Educational Content
# 4       8                       Educational Content
# 5       9                       Educational Content
# 6      11                       Educational Content
# 7      12                       Educational Content
# 8      17                       Educational Content
# 9      18                       Educational Content
# 10     19                       Educational Content
# 11     21                      CE and Certification
# 12     23                      CE and Certification
# 13     24                      CE and Certification
# 14     25                   Presentation and Access
# 15     26                   Presentation and Access
# 16     27                   Presentation and Access
# 17     28                   Presentation and Access
# 18     29                   Presentation and Access
# 19     30                   Presentation and Access
# 20     33                   Presentation and Access
# 21     34                   Presentation and Access
# 22     35                   Presentation and Access
# 23     36                   Presentation and Access
# 24     37                   Presentation and Access
# 25     38               Communication and Marketing
# 26     39               Communication and Marketing
# 27     40               Communication and Marketing
# 28     41               Communication and Marketing
# 29     42               Communication and Marketing
# ..    ...                                       ...
# 94     58                 Assessment and Evaluation
# 95     59                 Assessment and Evaluation
# 96     61                 Assessment and Evaluation
# 97     62                 Assessment and Evaluation
# 98     63                 Assessment and Evaluation
# 99     65                 Assessment and Evaluation
# 100    69                 Assessment and Evaluation
# 101    70                 Assessment and Evaluation
# 102    71                 Assessment and Evaluation
# 103    72                 Assessment and Evaluation
# 104    75                 Assessment and Evaluation
# 105    77  Internationalization and Personalization
# 106    78  Internationalization and Personalization
# 107    81                    Tracking and Reporting
# 108    82                    Tracking and Reporting
# 109    85                    Tracking and Reporting
# 110    88                       Support and Service
# 111    89                       Support and Service
# 112    90                       Support and Service
# 113    91                       Support and Service
# 114    94          Technical Topics and Integration
# 115    96          Technical Topics and Integration
# 116    98          Technical Topics and Integration
# 117   100          Technical Topics and Integration
# 118   101          Technical Topics and Integration
# 119   103          Technical Topics and Integration
# 120   106          Technical Topics and Integration
# 121   107          Technical Topics and Integration
# 122   113                       Content Development
# 123   124                       Content Development
#
#                                                    req ADHA Priority  \
# 0    Ability to import and launch non-SCORM complia...             M
# 1    Ability to configure one or more types of digi...             M
# 2    Ability to manage registration and access for ...             M
# 3    Ability to create/configure extended, facilita...             M
# 4      Ability to set enrollment durations for courses             M
# 5    Ability to configure and enforce a certificati...             M
# 6    Ability to assign documents from a central doc...             M
# 7    Ability to offer closed discussion forums that...             M
# 8    Ability to associate multiple assessments with...             M
# 9    Ability to block access to course content unti...             M
# 10   Ability to associate an evaluation (survey) wi...             M
# 11   Ability for system to automatically issue cred...             M
# 12   Ability for users to self-report externally-ea...             M
# 13   Ability to award users with a personalized PDF...             M
# 14   Ability to customize the look, feel, and navig...             M
# 15   Ability for user to search and browse the cont...             M
# 16   Ability to create tags and apply them to learn...             M
# 17   Ability for visitors to the end user site to b...             M
# 18   Ability for the catalog to present and apply d...             M
# 19   Shopping cart/e-commerce capabilities that ena...             M
# 20   Ability for a user to access a course or other...             M
# 21   Ability to bulk import/register a list of user...             M
# 22   Ability to define groups, roles, and permissio...             M
# 23   Ability to provide distinctly branded/co-brand...             M
# 24   Ability for a designated administrator to mana...             M
# 25   Ability to configure and automate e-mail commu...             M
# 26   Configurable, automated confirmation e-mail se...             M
# 27   Configurable, automated reminder e-mail sent p...             M
# 28   Configurable, automated follow up e-mail sent ...             M
# 29   Ability to manually create and send e-mails to...             M
# ..                                                 ...           ...
# 94   Ability for assessment (test) and survey be pa...             S
# 95   Ability to publish an evaluation (survey) as a...             S
# 96   Ability to re-use a single evaluation (not cop...             S
# 97   Ability to easily insert graphics into an asse...             S
# 98   Ability to easily insert graphics into an asse...             S
# 99   Ability to apply branching or skip logic based...             S
# 100  Ability to score test in real time and send en...             S
# 101  Ability to insert page breaks where desired in...             S
# 102  Ability to insert page breaks where desired in...             S
# 103  Item analysis to see how assessment (test) que...             S
# 104  Ability for end users to bookmark their place ...             S
# 105  Ability to provide closed captioning or third ...             S
# 106  Ability to deploy the system in multiple langu...             S
# 107  Ability to track where users are in a course, ...             S
# 108  Ability for an ADHA administrator to configure...             S
# 109  Ability to compare pre-test and post-test data...             S
# 110                 Phone-based support for ADHA staff             S
# 111                 E-mail based support for end users             S
# 112               Online knowledge base for ADHA staff             S
# 113                Online knowledge base for end users             S
# 114  Ability to sub-license the LMS to other groups...             S
# 115            Ability to host/support streaming media             S
# 116  Ability to receive registration and enrollment...             S
# 117  Ability to support single sign-on with a Webin...             S
# 118  Ability to support deeper integration with Zoo...             S
# 119                Ability to support federated search             S
# 120              Ability to add custom database fields             S
# 121                   Separate app-based access to LMS             S
# 122  Ability to have external users (e.g., editoria...             S
# 123  Can the LMS host links to other LMS providers ...             S
#
#                                        Notes to Vendor  rating resp
# 0    This content might include, for example, recor...     NaN  NaN
# 1    This might include, for example, combining mul...     NaN  NaN
# 2    ADHA currently uses Zoom. It should be possibl...     NaN  NaN
# 3    For example, it should be possible to configur...     NaN  NaN
# 4    Please specify how enrollment durations can be...     NaN  NaN
# 5    This should include, for example, the ability ...     NaN  NaN
# 6    Updating a document in the central repository ...     NaN  NaN
# 7    It should be possible to associate a discussio...     NaN  NaN
# 8    This applies to both on-demand and facilitated...     NaN  NaN
# 9                                                  NaN     NaN  NaN
# 10   This applies to both on-demand and facilitated...     NaN  NaN
# 11                                                 NaN     NaN  NaN
# 12                                                 NaN     NaN  NaN
# 13   ADHA offers learning products that qualify for...     NaN  NaN
# 14   Please indicate how this would be achieved (e....     NaN  NaN
# 15   Please indicate whether search in your system ...     NaN  NaN
# 16   Please indicate whether there are any types of...     NaN  NaN
# 17   Note: For this item and all other items relate...     NaN  NaN
# 18                                                 NaN     NaN  NaN
# 19                                                 NaN     NaN  NaN
# 20   For example, ADHA may pursue organizational pu...     NaN  NaN
# 21   ADHA often registers full cohorts of students ...     NaN  NaN
# 22   It should be possible for users to have multip...     NaN  NaN
# 23   ADHA often partners with corporates to offer w...     NaN  NaN
# 24   Preferably multiple administrators would be ab...     NaN  NaN
# 25   Some specific types of e-mail communication ar...     NaN  NaN
# 26   ADHA should be able to specify the content of ...     NaN  NaN
# 27   ADHA should be able to specify the content of ...     NaN  NaN
# 28   ADHA should be able to specify the content of ...     NaN  NaN
# 29                                                 NaN     NaN  NaN
# ..                                                 ...     ...  ...
# 94   The ability to combine assessments and surveys...     NaN  NaN
# 95                                                 NaN     NaN  NaN
# 96   The goal here is to be able to use a single, s...     NaN  NaN
# 97                                                 NaN     NaN  NaN
# 98                                                 NaN     NaN  NaN
# 99   This might come into play with the design of t...     NaN  NaN
# 100                                                NaN     NaN  NaN
# 101                                                NaN     NaN  NaN
# 102                                                NaN     NaN  NaN
# 103                                                NaN     NaN  NaN
# 104                                                NaN     NaN  NaN
# 105  ADHA wants to be ADA compliant and providing r...     NaN  NaN
# 106  Please indicate the languages other than Engli...     NaN  NaN
# 107                                                NaN     NaN  NaN
# 108                                                NaN     NaN  NaN
# 109                                                NaN     NaN  NaN
# 110  Please comment on hours of operation and typic...     NaN  NaN
# 111                                                NaN     NaN  NaN
# 112                                                NaN     NaN  NaN
# 113                                                NaN     NaN  NaN
# 114  ADHA is very interested in this model, it is m...     NaN  NaN
# 115  Please indicate how you handle streaming video...     NaN  NaN
# 116  ADHA uses iMIS for eCommerce along with Great ...     NaN  NaN
# 117  ADHA currently uses Zoom. Please indicate whet...     NaN  NaN
# 118  Please describe the types of beyond-SSO integr...     NaN  NaN
# 119  To provide users with as full a view as possib...     NaN  NaN
# 120  Please comment on how custom fields work in yo...     NaN  NaN
# 121  Do you provide access to the LMS through indep...     NaN  NaN
# 122  Please describe the process for having ADHA cr...     NaN  NaN
# 123  ADHA intends to become a clearing house of den...     NaN  NaN
#
# [124 rows x 7 columns]

# %%
import difflib
# difflib.SequenceMatcher(None, 'hello world', 'hello').ratio()

def respondToReq(req, corpus):
    '''
    Given a requirement (req.req) and a dataframe 'corpus' of past responses
    Read through the corpus (corpus.req) to find the past requirement that most closely matches the requirement
    Overwrite the response (req.resp) and rating (req.rating) with that requirement's response.
    '''
    
    # req.match exists to hold the match ratio which we get from the 'difflib' library
    req.match = 0
    
    print("...processing requirement ", req.req)
    
    for index, row in corpus.iterrows():
        # this generates a number between 0 and 1 with the similarity of two strings
        try:
            ratio = difflib.SequenceMatcher(None, row.req, req.req).ratio()
        except: 
            ratio = 0
            # print("SequenceMatcher choked on row.req = ", row.req, " , req.req = ", req.req)
        
        # if this is the highest ratio we've found, update the requirement row to match the corpus row
        if ratio > req.match:
            req.resp = row.resp
            req.rating = row.rating
            req.match = ratio
    
    return req

def output_response(corpus, RFP):
    '''
    Given a 'corpus' of past answers
    output an RFP response as a dataframe
    that duplicates previous responses to all exactly matching requirements 
    match on requirement language
    '''
    
    # add a column to the response RFP to hold the match ratio
    RFP['match'] = pd.Series()
    
    # read through each line of the RFP, filling in responses to requirements
    filledRFP = RFP.apply(respondToReq, corpus = corpus, axis = "columns")
    
    return filledRFP


filledRFP = output_response(corpus, newRFP)

filledRFP.to_csv("adha_filled.csv", na_rep = "", index = False, encoding = 'utf-8')
# Out:
# ...processing requirement  Ability to import and launch non-SCORM compliant content
# ...processing requirement  Ability to import and launch non-SCORM compliant content
# ...processing requirement  Ability to configure one or more types of digital content into a course experience
# ...processing requirement  Ability to manage registration and access for live Webinar
# ...processing requirement  Ability to create/configure extended, facilitated online courses (e.g., a course an instructor leads over a period weeks using discussion, readings, assignments, etc.)
# ...processing requirement  Ability to set enrollment durations for courses
# ...processing requirement  Ability to configure and enforce a certification or learning path involving multiple courses/activities.
# ...processing requirement  Ability to assign documents from a central document repository to multiple courses
# ...processing requirement  Ability to offer closed discussion forums that can only be accessed based upon permission being granted by ADHA or as part of being enrolled in a specific class
# ...processing requirement  Ability to associate multiple assessments with a course (e.g., pre-test, post-test) and tie progress and completion to satisfactory scores
# ...processing requirement  Ability to block access to course content until a pre-test is successfully completed
# ...processing requirement  Ability to associate an evaluation (survey) with a course and require completion of the evaluation for completion or credit in the course
# ...processing requirement  Ability for system to automatically issue credit upon successful completion of a course
# ...processing requirement  Ability for users to self-report externally-earned credit (e.g. courses earned at state conferences or through other LMSs) for inclusion in their transcript
# ...processing requirement  Ability to award users with a personalized PDF certificate based upon successful completion of a course
# ...processing requirement  Ability to customize the look, feel, and navigation of the end user site to reflect ADHA's branding requirements
# ...processing requirement  Ability for user to search and browse the content available in the system based on keywords and phrases and categories
# ...processing requirement  Ability to create tags and apply them to learning materials to facilitate end users' searching within the site
# ...processing requirement  Ability for visitors to the end user site to browse a catalog of products available for purchase/enrollment without having to be logged in
# ...processing requirement  Ability for the catalog to present and apply different pricing based on user groups (e.g., member/non-member, faculty, student)
# ...processing requirement  Shopping cart/e-commerce capabilities that enable a user to pay for a course in the catalog with a credit card and be automatically enrolled into a course.
# ...processing requirement  Ability for a user to access a course or other product by submitting a code
# ...processing requirement  Ability to bulk import/register a list of users (e.g., from an Excel file)
# ...processing requirement  Ability to define groups, roles, and permissions that determine the type and level of access a user has to the system (e.g., administrator, instructor, end user) and the user's ability to make changes
# ...processing requirement  Ability to provide distinctly branded/co-branded instances or areas of the site for groups (sub-sites)
# ...processing requirement  Ability for a designated administrator to manage users and enrollments within a sub-site
# ...processing requirement  Ability to configure and automate e-mail communication from the platform on a course-by-course basis
# ...processing requirement  Configurable, automated confirmation e-mail sent upon completion of enrollment
# ...processing requirement  Configurable, automated reminder e-mail sent prior to start of course on date/time specified by ADHA
# ...processing requirement  Configurable, automated follow up e-mail sent at a time specified by ADHA after conclusion of course
# ...processing requirement  Ability to manually create and send e-mails to specific groups within the system (including all users)
# ...processing requirement  Ability to manually create and send e-mails on a course-by-course basis
# ...processing requirement  Ability to apply ADHA branding to e-mails
# ...processing requirement  Ability to customize recommendations for learning products to individual learners based on past enrollments and purchases (e.g., since you bought X, you might also like Y) and profile data (e.g., geographic location or specialty)
# ...processing requirement  All non-protected site pages (and, in particular, catalog pages) indexable by external search engines (e.g., Google)
# ...processing requirement  Ability to bundle courses together for purchase
# ...processing requirement  Ability to offer coupons, discounts, and give-aways
# ...processing requirement  Ability to author assessments (tests) that can be associated with a course/activity
# ...processing requirement  Ability to publish an assessment (test) as a stand alone item (i.e., not associated with a course)
# ...processing requirement  Ability to store assessment (test) items in a question bank for re-use across multiple assessments
# ...processing requirement  Ability to copy existing assessments (tests) for creating a new ones
# ...processing requirement  Ability to author evaluations (surveys) that can be associated with a course
# ...processing requirement  Ability to copy existing evaluations (surveys) for creating new ones
# ...processing requirement  Ability to specify the number of times an end user may complete an assessment (test)
# ...processing requirement  Ability to specify the number of times an end user may complete an evaluation (survey)
# ...processing requirement  Ability for a learner to view a transcript with their status in courses (e.g., complete/in progress, etc.), scores, credit earned, and ability to download any certificates that have been issued
# ...processing requirement  Ability for authorized administrator to generate reports on major system data (e.g., course enrollments, course completions, assessment and evaluation data, and course access code use)
# ...processing requirement  Ability to export all report data in an analyzable, manipulable format (e.g., CSV, XLS, or tab-delimited form)
# ...processing requirement  Training for ADHA staff
# ...processing requirement  E-mail based support for ADHA staff
# ...processing requirement  Dedicated account manager
# ...processing requirement  Compatible with all major operating systems and browsers
# ...processing requirement  Vendor-hosted solution
# ...processing requirement  Ability to support single sign-on with iMIS
# ...processing requirement  Ability to pass data (e.g., course enrollments, completions, and scores) back to iMIS
# ...processing requirement  Ability to deliver and track content on mobile devices (e.g., iPhone, iPad, Android)
# ...processing requirement  Structured exposure of all data collected/generated by the system for export to/consumption by 3rd-party applications.
# ...processing requirement  Please discuss your merchant compatability for credit card processing and include any information about your PCI compliance.
# ...processing requirement  Ability to create learning content with built-in content authoring functionality
# ...processing requirement  Ability to import and configure content developed in external tools, such as Articulate, Captivate, and Lectora
# ...processing requirement  Ability to support the import of SCORM, AICC, or xAPI compliant content
# ...processing requirement  Ability to create reusable learning objects that can be incorporated into different educational offerings
# ...processing requirement  Ability to categorize content objects based on (1) topics, (2) level of education, (3) audience, and (4) learning objectives
# ...processing requirement  Ability for both internal and external content creators to upload documents to the platform
# ...processing requirement  Ability to import PowerPoint, MS Word, Excel, Visio, HTML pages, PDF, etc.
# ...processing requirement  Ability to flag content changes and provide user with the option to view specific revisions
# ...processing requirement  Ability to assemble media objects and files (e.g., PDF, PPT, and Word) into distinct Web-based courses
# ...processing requirement  Ability to embed media objects such as videos into Web-based courses
# ...processing requirement  Ability to incorporate quizzes or tests into a course, preferably pulled from a central item bank of questions that is also categorized based on topic, level of education, audience and learning objectives
# ...processing requirement  Ability to have a workflow in place to help facilitate course creation that steps staff through the development of a course (i.e., a course creation wizard)
# ...processing requirement  The ability  to allow multiple users to edit, review, and approve content
# ...processing requirement  Ability to configure and manage live, place-based courses in the system
# ...processing requirement  Real-time chat tool for communication between learners and instructors
# ...processing requirement  Other peer-to-peer communication tools to support social learning
# ...processing requirement  Ability to configure and issue multiple types of credit for the same course
# ...processing requirement  Ability to manage purchases made by purchase order
# ...processing requirement  Does the LMS allow for ad space to be sold by host organization? Are there any limitations if this is allowed?
# ...processing requirement  Ability to randomize the questions used in an assessment (test)
# ...processing requirement  Ability to easily insert rich-media (e.g., video) into an assessment (test) question
# ...processing requirement  Ability to apply branching or skip logic based on the answer to a question in an evaluation (survey)
# ...processing requirement  Ability for end users to see their responses to an assessment (test) and see that compared to others completing the assessment
# ...processing requirement  Ability for test takers to see what questions they got wrong.
# ...processing requirement  Ability to link assessment items or question banks to a learning objective and generate tests that cover each learning objective
# ...processing requirement  Ability to export all report data in a nicely formatted format (e.g., PDF or HTML)
# ...processing requirement  Ability to create and edit content both online and offline
# ...processing requirement  Ability to have content consisting of games or competitions
# ...processing requirement  Ability to import, launch, and track SCORM-compliant content
# ...processing requirement  Ability to blend place-based and online learning into a unified learning experience
# ...processing requirement  Ability to offer open discussion forums that any user in the platform can join
# ...processing requirement  Ability for learners to upload content for review by the instructor for a course
# ...processing requirement  Ability for learners to upload content for review by other learners enrolled in the same course
# ...processing requirement  Ability for users to claim credit, including specifying the amount of credit earned, after completing a course and (if required) completing the evaluation
# ...processing requirement  Ability to support payment plans (e.g., a series of payments over time) for courses
# ...processing requirement  Ability for users to rate learning products
# ...processing requirement  Ability for users to review learning products
# ...processing requirement  Ability for assessment (test) and survey be part of the same evaluation so participants don't have to take separate evaluations (one for test and one for survey
# ...processing requirement  Ability to publish an evaluation (survey) as a stand alone item (i.e., not associated with an online course)
# ...processing requirement  Ability to re-use a single evaluation (not copies) across multiple courses/activities
# ...processing requirement  Ability to easily insert graphics into an assessment (test) question
# ...processing requirement  Ability to easily insert graphics into an assessment (test) answer
# ...processing requirement  Ability to apply branching or skip logic based on the answer to a question in an assessment (test)
# ...processing requirement  Ability to score test in real time and send end user results
# ...processing requirement  Ability to insert page breaks where desired in assessments (tests)
# ...processing requirement  Ability to insert page breaks where desired in evaluations (surveys)
# ...processing requirement  Item analysis to see how assessment (test) questions perform
# ...processing requirement  Ability for end users to bookmark their place in an assessment (i.e., allow users to leave a test and return later to complete it)
# ...processing requirement  Ability to provide closed captioning or third party integrations for closed captioning.
# ...processing requirement  Ability to deploy the system in multiple languages
# ...processing requirement  Ability to track where users are in a course, what materials they have viewed and downloaded, including PDFs, video, audio, and Webinar attendance
# ...processing requirement  Ability for an ADHA administrator to configure ad hoc reports based on criteria determined by ADHA
# ...processing requirement  Ability to compare pre-test and post-test data by individual, group, or across all users
# ...processing requirement  Phone-based support for ADHA staff
# ...processing requirement  E-mail based support for end users
# ...processing requirement  Online knowledge base for ADHA staff
# ...processing requirement  Online knowledge base for end users
# ...processing requirement  Ability to sub-license the LMS to other groups (e.g. a state affiliate) to allow them to have a portal of their own, run by the nation ADHA with some ability to create their own content.
# ...processing requirement  Ability to host/support streaming media
# ...processing requirement  Ability to receive registration and enrollment data from ADHA's custom e-commerce system after the completion of an order and auto-create the appropriate accounts and enrollments
# ...processing requirement  Ability to support single sign-on with a Webinar platform
# ...processing requirement  Ability to support deeper integration with Zoom (e.g., to use attendance data from the Webinar to mark the corresponding module or course complete in the platform)
# ...processing requirement  Ability to support federated search
# ...processing requirement  Ability to add custom database fields
# ...processing requirement  Separate app-based access to LMS
# ...processing requirement  Ability to have external users (e.g., editorial board) use back-end system to create the educational content
# ...processing requirement  Can the LMS host links to other LMS providers and share completion information back via and API?

# %%
# TODO
# fix ingest so it doesn't use dicts 
# add date of response
# add Health / Trade / Other
