# %%
# read in CSVs of requirements, ratings, and responses as a dataframe
# Cobb-specific
import numpy as np
import pandas as pd

def ingestRFP(file, start_row = 0, end_row = 999, req_i = 2, rat_i = 5, resp_i =6):
    '''
    filelist is a file path to a CSV for a proposal
    req_i is the column index for requirements
    resp_i is the column index for responses
    start_row is the row to start reading on
    end_row is the row to stop reading on
    outputs a dataframe of requirement-response pairs
    
    '''
    
    # NOTE: in Excel, save as CSV UTF-8
    rfp_df = pd.read_table(file, sep = ",", skipinitialspace = True)
    
    # TODO: stop doing this as a dict; it doesn't maintain the order. 
    # create a stripped dict
    strip_dict = {
        "req" : rfp_df.iloc[start_row:end_row, req_i],
        "rating" : rfp_df.iloc[start_row:end_row, rat_i],
        "resp" : rfp_df.iloc[start_row:end_row, resp_i]
    }
    
    # first rows, then columns
    return pd.DataFrame(strip_dict)



# add date of response
# add Health / Trade / Other
# save as a file 
corpus = ingestRFP('corpus.csv', 7, 11, 2, 6, 7)
# output_response(corpus, corpus)
newRFP = ingestRFP('newRFP.csv', 7, 11, 2, 6, 7)

newRFP

# cps[cps.union.isin(["Union"])]

matchRows = newRFP.req.isin(corpus.req)
matchRows

# 1. exact match to a CSV of requirements with no responses 
# fill the most recent responses
# output to CSV (or XLS)

# 2. score the non-exact matches by some similarity algorithm
# fill the highest scoring responses

# 3. come up with a way of scoring
# Out:
# 7      True
# 8     False
# 9      True
# 10    False
# Name: req, dtype: bool

# %%
import difflib
# difflib.SequenceMatcher(None, 'hello world', 'hello').ratio()

def respondToReq(req, corpus):
    '''
    Given a requirement (req.req) and a dataframe 'corpus' of past responses
    Read through the corpus (corpus.req) to find the past requirement that most closely matches the requirement
    Overwrite the response (req.resp) and rating (req.rating) with that requirement's response.
    '''
    
    max_ratio = 0
    
    for index, row in corpus.iterrows():
        # this generates a number between 0 and 1 with the similarity of two strings
        try:
            lrat = difflib.SequenceMatcher(None, row.req, req.req).ratio()
        except: 
            lrat = 0
            print("SequenceMatcher choked on row.req = ", row.req, " , req.req = ", req.req)
        
        if lrat > max_ratio:
            max_ratio = lrat
            req.resp = row.resp
            req.rating = row.rating
    
    return req

def output_response(corpus, RFP):
    '''
    Given a 'corpus' of past answers
    output an RFP response in CSV format
    that duplicates previous responses to all exactly matching requirements 
    match on requirement language
    '''
    
    # read through each line of the RFP
    # using apply
    
    # send the arguments after the first to df.apply() like this:
    filledRFP = RFP.apply(respondToReq, corpus = corpus, axis = "columns") #, corpus)
    # axis = 'columns' tells apply to apply itself to each row. 

    return filledRFP

# (file, start_row = 0, end_row = 999, req_i = 2, rat_i = 5, resp_i =6)

corpus = ingestRFP('C:/Users/ahicken/Documents/proposal_data/naedutf8.csv', 9, 230, 2, 6, 7)
# last row should be 230

newRFP = ingestRFP('C:/Users/ahicken/Documents/proposal_data/adha.csv', 9, 132, 2, 5, 6)
# last row should be 132

filledRFP = output_response(corpus, newRFP)

filledRFP
# Out:
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to manage registration and access for live Webinar
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to manage registration and access for live Webinar
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to create/configure extended, facilitated online courses (e.g., a course an instructor leads over a period weeks using discussion, readings, assignments, etc.)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to set enrollment durations for courses
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to configure and enforce a certification or learning path involving multiple courses/activities.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to assign documents from a central document repository to multiple courses
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to offer closed discussion forums that can only be accessed based upon permission being granted by ADHA or as part of being enrolled in a specific class
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to associate multiple assessments with a course (e.g., pre-test, post-test) and tie progress and completion to satisfactory scores
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to block access to course content until a pre-test is successfully completed
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to associate an evaluation (survey) with a course and require completion of the evaluation for completion or credit in the course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for system to automatically issue credit upon successful completion of a course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for users to self-report externally-earned credit (e.g. courses earned at state conferences or through other LMSs) for inclusion in their transcript
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to award users with a personalized PDF certificate based upon successful completion of a course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to customize the look, feel, and navigation of the end user site to reflect ADHA's branding requirements
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for user to search and browse the content available in the system based on keywords and phrases and categories
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to create tags and apply them to learning materials to facilitate end users' searching within the site
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for visitors to the end user site to browse a catalog of products available for purchase/enrollment without having to be logged in
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for the catalog to present and apply different pricing based on user groups (e.g., member/non-member, faculty, student)
# SequenceMatcher choked on row.req =  nan  , req.req =  Shopping cart/e-commerce capabilities that enable a user to pay for a course in the catalog with a credit card and be automatically enrolled into a course.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for a user to access a course or other product by submitting a code
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to bulk import/register a list of users (e.g., from an Excel file)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to define groups, roles, and permissions that determine the type and level of access a user has to the system (e.g., administrator, instructor, end user) and the user's ability to make changes
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to provide distinctly branded/co-branded instances or areas of the site for groups (sub-sites)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for a designated administrator to manage users and enrollments within a sub-site
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to configure and automate e-mail communication from the platform on a course-by-course basis
# SequenceMatcher choked on row.req =  nan  , req.req =  Configurable, automated confirmation e-mail sent upon completion of enrollment
# SequenceMatcher choked on row.req =  nan  , req.req =  Configurable, automated reminder e-mail sent prior to start of course on date/time specified by ADHA
# SequenceMatcher choked on row.req =  nan  , req.req =  Configurable, automated follow up e-mail sent at a time specified by ADHA after conclusion of course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to manually create and send e-mails to specific groups within the system (including all users)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to manually create and send e-mails on a course-by-course basis
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to apply ADHA branding to e-mails
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to customize recommendations for learning products to individual learners based on past enrollments and purchases (e.g., since you bought X, you might also like Y) and profile data (e.g., geographic location or specialty)
# SequenceMatcher choked on row.req =  nan  , req.req =  All non-protected site pages (and, in particular, catalog pages) indexable by external search engines (e.g., Google)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to bundle courses together for purchase
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to offer coupons, discounts, and give-aways
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to author assessments (tests) that can be associated with a course/activity
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to publish an assessment (test) as a stand alone item (i.e., not associated with a course)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to store assessment (test) items in a question bank for re-use across multiple assessments
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to copy existing assessments (tests) for creating a new ones
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to author evaluations (surveys) that can be associated with a course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to copy existing evaluations (surveys) for creating new ones
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to specify the number of times an end user may complete an assessment (test)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to specify the number of times an end user may complete an evaluation (survey)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for a learner to view a transcript with their status in courses (e.g., complete/in progress, etc.), scores, credit earned, and ability to download any certificates that have been issued
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for authorized administrator to generate reports on major system data (e.g., course enrollments, course completions, assessment and evaluation data, and course access code use)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to export all report data in an analyzable, manipulable format (e.g., CSV, XLS, or tab-delimited form)
# SequenceMatcher choked on row.req =  nan  , req.req =  Training for ADHA staff
# SequenceMatcher choked on row.req =  nan  , req.req =  E-mail based support for ADHA staff
# SequenceMatcher choked on row.req =  nan  , req.req =  Dedicated account manager
# SequenceMatcher choked on row.req =  nan  , req.req =  Compatible with all major operating systems and browsers
# SequenceMatcher choked on row.req =  nan  , req.req =  Vendor-hosted solution
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support single sign-on with iMIS
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to pass data (e.g., course enrollments, completions, and scores) back to iMIS
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to deliver and track content on mobile devices (e.g., iPhone, iPad, Android)
# SequenceMatcher choked on row.req =  nan  , req.req =  Structured exposure of all data collected/generated by the system for export to/consumption by 3rd-party applications.
# SequenceMatcher choked on row.req =  nan  , req.req =  Please discuss your merchant compatability for credit card processing and include any information about your PCI compliance.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to create learning content with built-in content authoring functionality
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to import and configure content developed in external tools, such as Articulate, Captivate, and Lectora
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support the import of SCORM, AICC, or xAPI compliant content
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to create reusable learning objects that can be incorporated into different educational offerings
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to categorize content objects based on (1) topics, (2) level of education, (3) audience, and (4) learning objectives
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for both internal and external content creators to upload documents to the platform
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to import PowerPoint, MS Word, Excel, Visio, HTML pages, PDF, etc.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to flag content changes and provide user with the option to view specific revisions
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to assemble media objects and files (e.g., PDF, PPT, and Word) into distinct Web-based courses
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to embed media objects such as videos into Web-based courses
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to incorporate quizzes or tests into a course, preferably pulled from a central item bank of questions that is also categorized based on topic, level of education, audience and learning objectives
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to have a workflow in place to help facilitate course creation that steps staff through the development of a course (i.e., a course creation wizard)
# SequenceMatcher choked on row.req =  nan  , req.req =  The ability  to allow multiple users to edit, review, and approve content
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to configure and manage live, place-based courses in the system
# SequenceMatcher choked on row.req =  nan  , req.req =  Real-time chat tool for communication between learners and instructors
# SequenceMatcher choked on row.req =  nan  , req.req =  Other peer-to-peer communication tools to support social learning
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to configure and issue multiple types of credit for the same course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to manage purchases made by purchase order
# SequenceMatcher choked on row.req =  nan  , req.req =  Does the LMS allow for ad space to be sold by host organization? Are there any limitations if this is allowed?
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to randomize the questions used in an assessment (test)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to easily insert rich-media (e.g., video) into an assessment (test) question
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to apply branching or skip logic based on the answer to a question in an evaluation (survey)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for end users to see their responses to an assessment (test) and see that compared to others completing the assessment
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for test takers to see what questions they got wrong.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to link assessment items or question banks to a learning objective and generate tests that cover each learning objective
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to export all report data in a nicely formatted format (e.g., PDF or HTML)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to create and edit content both online and offline
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to have content consisting of games or competitions
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to import, launch, and track SCORM-compliant content
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to blend place-based and online learning into a unified learning experience
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to offer open discussion forums that any user in the platform can join
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for learners to upload content for review by the instructor for a course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for learners to upload content for review by other learners enrolled in the same course
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for users to claim credit, including specifying the amount of credit earned, after completing a course and (if required) completing the evaluation
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support payment plans (e.g., a series of payments over time) for courses
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for users to rate learning products
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for users to review learning products
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for assessment (test) and survey be part of the same evaluation so participants don't have to take separate evaluations (one for test and one for survey
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to publish an evaluation (survey) as a stand alone item (i.e., not associated with an online course)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to re-use a single evaluation (not copies) across multiple courses/activities
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to easily insert graphics into an assessment (test) question
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to easily insert graphics into an assessment (test) answer
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to apply branching or skip logic based on the answer to a question in an assessment (test)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to score test in real time and send end user results
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to insert page breaks where desired in assessments (tests)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to insert page breaks where desired in evaluations (surveys)
# SequenceMatcher choked on row.req =  nan  , req.req =  Item analysis to see how assessment (test) questions perform
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for end users to bookmark their place in an assessment (i.e., allow users to leave a test and return later to complete it)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to provide closed captioning or third party integrations for closed captioning.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to deploy the system in multiple languages
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to track where users are in a course, what materials they have viewed and downloaded, including PDFs, video, audio, and Webinar attendance
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability for an ADHA administrator to configure ad hoc reports based on criteria determined by ADHA
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to compare pre-test and post-test data by individual, group, or across all users
# SequenceMatcher choked on row.req =  nan  , req.req =  Phone-based support for ADHA staff
# SequenceMatcher choked on row.req =  nan  , req.req =  E-mail based support for end users
# SequenceMatcher choked on row.req =  nan  , req.req =  Online knowledge base for ADHA staff
# SequenceMatcher choked on row.req =  nan  , req.req =  Online knowledge base for end users
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to sub-license the LMS to other groups (e.g. a state affiliate) to allow them to have a portal of their own, run by the nation ADHA with some ability to create their own content.
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to host/support streaming media
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to receive registration and enrollment data from ADHA's custom e-commerce system after the completion of an order and auto-create the appropriate accounts and enrollments
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support single sign-on with a Webinar platform
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support deeper integration with Zoom (e.g., to use attendance data from the Webinar to mark the corresponding module or course complete in the platform)
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to support federated search
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to add custom database fields
# SequenceMatcher choked on row.req =  nan  , req.req =  Separate app-based access to LMS
# SequenceMatcher choked on row.req =  nan  , req.req =  Ability to have external users (e.g., editorial board) use back-end system to create the educational content
# SequenceMatcher choked on row.req =  nan  , req.req =  Can the LMS host links to other LMS providers and share completion information back via and API?
# SequenceMatcher choked on row.req =  Ability to automatically assign users to groups based on user profile attributes  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create child groups to which a user may be assigned.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to restrict what a user can edit in his/her profile down to the individual field level  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically present authorized content based on system knowledge of a logged in user (e.g., system groups or roles, profile data)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically present recommended content based on system knowledge of a logged in user (e.g., system groups or roles, profile data, past behavior)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to create, change, and view user information/profile  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to copy an existing role  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to assign multiple roles to one user account  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create custom fields in user profiles without intervention from vendor  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to or batch upload new users without vendor assistance  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set/change user status from active to inactive  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to transfer a user from one group (e.g.,member company) to another  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to designate/change a user's supervisor  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to view user activity, including dates, times, and specific pages visited  , req.req =  nan
# SequenceMatcher choked on row.req =  Configurable dashboard/home page that allows reports to be viewed on home page  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create splash pages that appear for users upon initial log-in or next log-in to convey important notices   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to view dashboard data, adjusted by role (Learner/Supervisor/Administrator)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to toggle between role types while remaining logged in; all-in-1 view of user roles  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for authorized administrator to deploy only required functionality (turning on or off features, modules, permissions)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for authorized administrator to configure all end user interface navigation without vendor involvement  , req.req =  nan
# SequenceMatcher choked on row.req =  Encryted secure repository that requires authentication via vendor server that stores documents, links to other websites, and videos (MP4, FLV, Wave)  , req.req =  nan
# SequenceMatcher choked on row.req =  Responsive interface design for display on common mobile devices and tablets  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create and add custom fields to user and course profiles  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to alphabetize or decide order of fields on user profile and course profiles  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to modify "out-of-the-box" or canned standard fields on user profile and course fields  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to provide distinctly branded/co-branded instances or areas of the site for access only by authorized groups (sub-sites, tenant sites)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to import, launch, and track SCORM-compliant content without vendor assistance  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to import, launch, and track TinCan/xAPI-compliant content without vendor assistance  , req.req =  nan
# SequenceMatcher choked on row.req =  Adherence to LTI 1.3  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to import and launch non-SCORM compliant content  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure one or more types of digital content into a course experience  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set enrollment durations for courses  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure multiple courses into a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set enrollment durations for curricula  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to edit the contents of a curriculum for all users  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to remove all learning activites from a curriculum and hide/inactivate curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to deactivate a course without having to remove it from curricula  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set specific due dates for curricula; access to curriculua tied to due date  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to update/modify number of days due for curriculum completion for multiple students  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to manage registration and access for live Webinar  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to support extended, facilitated online courses (e.g., a course an instructor leads over a period weeks using discussion, readings, assignments, etc.)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure and manage live, place-based courses in the system  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to input and configure a centralized list of instructors  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to assign multiple instructors to a class and/or session  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set pre-requisites for courses  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized user to waive a pre-requisite  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to approve/deny a request to waive a pre-requisite  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to restrict management of individual classes beyond permissions to specific groups or a set of users  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure a suggested learning path involving multiple courses/activities.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to enforce learning path involving multiple courses/activities.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to prescribe/suggest learning (e.g., based on past performance, analysis of strengths/weaknesses)   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to upload course-related documents to a centralized repository so that documents can be re-used across multiple courses.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a learner to submit a document for review by an authorized reviewer.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized reviewer to access a submitted document and submit feedback  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to publish a new version of a course while keeping past versions available to any users active in the past versions  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to delete courses if it impacts storage  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an administrator to manage completion status by marking any learning objects as complete, in-progress, not attempted, incomplete, or pending and designating a score, if applicable  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for administrator to grant a learner(s) the option to mark a course as complete  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set courses to renew automatically at specified times (i.e., for annual certification)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to grant access to educational content to allow group/member companies (sub-sites/tenants) so that they can grant access to their users   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to grant sub-site/tenant administrators rights to administor all capabilities addressed in this section for their own users.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author assessments (tests) in the system  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to import assessments (tests) authored externally from the system  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to "clone" existing assessments (tests) for creating new versions  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate any created or imported assessment with multiple courses (i.e., re-use the assessment across multiple courses)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate any created or imported assessment with multiple curricula (i.e., re-use the assessment across multiple curricula)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to edit assessments after some learners have completed them  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to remove or replace tests in a course that has already been published  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate multiple assessments with a course (e.g., pre-test, post-test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author single-answer multiple choice assessment (test) questions (e.g., radio button)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author multiple-answer multiple choice assessment (test) questions (e.g., checkbox)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author open text assessment (test) questions (i.e., users can enter text into a text field)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author matching assessment (test) questions (e.g., user must correctly match item in column A with item in Colum B)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author sequence assessment (test) questions (e.g., users are asked to put the steps of a process in the correct order)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author hotspot assessment (test) questions (where users must select the correct area of a graphic)   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author drag-and-drop assessment (test) questions  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to insert graphics into an assessment (test) question  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to insert graphics into an assessment (test) answer  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to insert rich-media (e.g., video) into an assessment (test) question  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to tag an assessment questions or otherwise indicate when it is associated with a specific course or courses, including the chapter, module, or topic with which the assessment is associated.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to store assessment (test) items in a question bank for re-use across multiple assessments  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically randomize which questions are included in an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically randomize the order in which questions are presented in an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically randomize the order in which distracters, or answer options, are presented in an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to provide answer feedback on a question-by-question basis  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to provide answer feedback(summary) only upon completion of the assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to provide answer feedback both on a question-by-question basis and upon completion of the assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to apply branching or skip logic based on the answer to a question in an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to specify the minimum score a learner must achieve in order to pass an assessment  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to specify the number of times an end user may complete an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set and enforce the amount of time allowed for taking an assessment (test)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to require passing score for an assessment for accessing, progressing in, and completing a course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to require passing score for an assessment for accessing,progressing in, and completing a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for student to test out of a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to overide/modify assessment scores  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author evaluations (surveys) that can be associated with a course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to import evaluations (surveys) authored externally from the system  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to "clone" existing assessments (tests) for creating  new versions  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate any created or imported evaluations with multiple courses (i.e., re-use the evaluation across multiple courses)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate any created or imported evaluations with multiple curricula (i.e., re-use the evaluation across multiple curricula)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to edit surveys after some learners have completed them  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to remove or replace surveys in a course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate an evaluation (survey) with a course and require completion of the evaluation for completion or credit in the course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate an evaluation (survey) with a curriculum and require completion of the evaluation for completion or credit in the curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author single-answer multiple choice evaluation (survey) questions (e.g., radio button)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author multiple-answer multiple choice  evaluation (survey) questions (e.g., checkbox)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author open text evaluation (survey) questions (i.e., users can enter text into a text field)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to author Likert scale / ratings scale evaluation (survey) questions  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to apply branching or skip logic based on the answer to a question in an evaluation (survey)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to associate a specified amount of credit with any course configured in the system  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for system to automtically issue credit based upon successful completion of a course.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for system to automtically issue credit based upon successful completion of a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for users to claim credit for place-based learning experiences (e.g., conference sessions after completing a course/session.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for users to self-report external learning activities  (e.g., courses/activities not configured in the LMS) for inclusion in their transcript  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for learners to view assigned/completed learning activities via a transcript  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to delete multiple records from transcript  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create custom course certificates that can be formatted to pull system data (date completed, coursename, duration, etc.)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to select from a repository of course certificate templates to use when creating a new certificate  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to award users with a personalized certificate based upon successful completion of a course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to award users with a personalized certificate based upon successful completion of a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to award users with a digital badge based upon successful completion of a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for learner to review/print a completion certificates (student accessible) for all active and inactive (retired) courses   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to review/print a completion certificate on behalf of a learner  , req.req =  nan
# SequenceMatcher choked on row.req =  Universal search functionality that searches all learner consumable items such as courses, classes, resources, and bundles  , req.req =  nan
# SequenceMatcher choked on row.req =  Search functionality returns results in a view similar to the most widely used search engines  , req.req =  nan
# SequenceMatcher choked on row.req =  Search functionality filters results based on what the user has permission to view/consume  , req.req =  nan
# SequenceMatcher choked on row.req =  Basic and advanced search functionality for each module (tagging)  , req.req =  nan
# SequenceMatcher choked on row.req =  Advanced search that includes custom user fields  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure a course catalog that allows for determining what type of information to display for authenticated vs. unauthenticated users  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to display a publicly accessible catalog (i.e., no login/authentication required) with ability to restrict enrollments   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to group or bundle courses together for enrollment  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to make curricula visible for enrollment through the catalog.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to seach course catalog by category/ curriculum/ bundle  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to designate and display specified courses as  "featured courses" (viewable via Dashboard)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to present a calendar of upcoming live courses (both online and off, for all roles assigned) with links from the calendar to a catalog/registration page for each item presented in the calendar  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to view catalog in multiple views (thumbnails, list etc)   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to hide content from catalog  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for learner to self-register/enroll in catalog items   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a learner to self un-enroll from an item  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to restrict learners from self-enrolling in an ILT  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to enroll an individual user into a course(s)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to manually assign a curriculum to an individual user  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to enroll a group of users in a course  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to enroll a group of users in multiple courses  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to manually assign a curriculum to a group  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to automatically assign learning activities (single or bundle) to specific users defined by specific user attributes (auto-assignment rules)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an authorized administrator to un-enroll an individual user from a course(s)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to set (and override) the maximum number of students for a course at the session level  , req.req =  nan
# SequenceMatcher choked on row.req =  Automatic waitlist functionality (user at top of waitlist is automatically enrolled when a space opens up)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to manage manage the waitlists and rosters  , req.req =  nan
# SequenceMatcher choked on row.req =  Create/edit prompt to drop students from learning activities  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to configure registration to require with supervisor approval  , req.req =  nan
# SequenceMatcher choked on row.req =  Automatically unassign courses within a curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to assign licenses (courses, bundles, curricula) to group/member company (sub-site, tenant)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for member organization administrators to assign licenses (for courses/curricula) to individuals  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, a course of behalf of an individual and enroll that individual in the course.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, a course of behalf of an individual and enroll that individual in the course.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, multiple courses of behalf of an individual and enroll that individual in the courses.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, a curriculum or bundle of courses on  behalf of an individual and enroll that individual in the curriculum or bundle.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, a course on behalf of multiple individuals and enroll those individuals in the course.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, multiple courses on behalf of multiple individuals and enrol those individuals in the courses.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for a member administrator to purchase, through e-commerce, a curriculum or bundle of courses on behalf of multiple individuals and enrol those individuals in the curriculum or bundle.  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for authorized administrator to generate reports on major system data (e.g., course enrollments, course completions, assessment and evaluation data)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for an administrator to configure "ad hoc" reports based on criteria determined by NAED - i.e., specifying fields to be included/not included in the report  , req.req =  nan
# SequenceMatcher choked on row.req =  Wizard-driven report creation (for custom/ad hoc reports)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to share created/configured reports with other adminstrative and supervisory users  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to determine what report data member admininstrators can see.    , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to export all report data in an analyzable, manipulable format (e.g., CSV, XLS, or tab-delimited form)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to export all report data into document and/or Web page format (e.g., PDF or HTML)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to generate item analyses to see how assessment (test) questions perform  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to compare pre-test and post-test data by individual, group, or across all users  , req.req =  nan
# SequenceMatcher choked on row.req =  Availability of reports on all major system data in real-time reporting (no lag time)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create dashboard reports within the interface  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to schedule reports for distribution at designated times to designated e-mail addresses  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to modify "out-of-the-box"/canned  reports  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create dashboard drill down reports  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to run reports on user resources activity  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to filter reports are by groups/member companies (sub-sites/tenants)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to pull report on any field (including custom fields) in database and test results   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to report on how many times a test has been attempted and the score of each attempt  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to sort a report by fields (i.e., alphabetically or chronological)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for supervisors to generate reports for subordinates  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to report on curriculum progress across groups/globally  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to view and pring student transcripts (viewable and printable)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to report on exam/quiz responses by criteria  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to resport on quiz results within courses (in addition to standalone/final exams)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to capture and report on course analytics such as page visits, duration to complete, assets clicked.  , req.req =  nan
# SequenceMatcher choked on row.req =  Set auto-reminder email for assigned students/instructors/managers/administrators regarding due date for entire course/curriculum  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to edit and manage content of notification message  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to turn on or off notification events per group, audience, etc.   , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to create customized notification messages by course, curriculum, member company  , req.req =  nan
# SequenceMatcher choked on row.req =  Email notifications integration with Outlook; .ical invites  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to send emails to user's email address listed in their profile  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to send emails to multiple learners  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to send/resent enrollment emails to selected users via the LMS  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to offer open discussion forums that any user authenticated user can join  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to offer closed discussion forums that can only be accessed based upon permission being granted by NAED or as part of being enrolled in a specific class.  , req.req =  nan
# SequenceMatcher choked on row.req =  Leaderboard capability for displaying participation/competion levels in learning activities  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for learners to provide to provide ratings/reviews of courses anonymously  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability for learners to provide course content feedback within course content  , req.req =  nan
# SequenceMatcher choked on row.req =  LMS automatically recommends other courses related to courses previously completed  , req.req =  nan
# SequenceMatcher choked on row.req =  Training for NAED staff  , req.req =  nan
# SequenceMatcher choked on row.req =  User group for NAED staff  , req.req =  nan
# SequenceMatcher choked on row.req =  E-mail based support for NAED staff - either 24/7 or aligned with NAED business hours   , req.req =  nan
# SequenceMatcher choked on row.req =  Phone-based support for NAED staff -  - either 24/7 or aligned with NAED business hours   , req.req =  nan
# SequenceMatcher choked on row.req =  Dedicated support representative for System Administrator to ask “how to” questions?  , req.req =  nan
# SequenceMatcher choked on row.req =  Dedicated account manager  , req.req =  nan
# SequenceMatcher choked on row.req =  Online knowledge base for end users  , req.req =  nan
# SequenceMatcher choked on row.req =  Compatible with all major operating systems and browsers   , req.req =  nan
# SequenceMatcher choked on row.req =  Plug-in installation center  , req.req =  nan
# SequenceMatcher choked on row.req =  Vendor-hosted solution (SaaS or cloud)  , req.req =  nan
# SequenceMatcher choked on row.req =  User testing/staging environment  , req.req =  nan
# SequenceMatcher choked on row.req =  Documented and tested application programming interfaces and/or Web services for all major system functionality and data  , req.req =  nan
# SequenceMatcher choked on row.req =  Experience integrating with iMIS  , req.req =  nan
# SequenceMatcher choked on row.req =  Experience integrating with OKTA (identity management)  , req.req =  nan
# SequenceMatcher choked on row.req =  Experience integrating with HubSpot  , req.req =  nan
# SequenceMatcher choked on row.req =  Exposure of all key user activity data for use in reports generated in other systems  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to stream large media files (e.g., video)  , req.req =  nan
# SequenceMatcher choked on row.req =  Ability to support single sign-on with a Webinar platform  , req.req =  nan
# SequenceMatcher choked on row.req =  Secure hosting for ancillary files with secure CDN; data modifications occur instantly across all systems  , req.req =  nan
# SequenceMatcher choked on row.req =  nan  , req.req =  nan
#                                                    req rating  \
# 9    Ability to manage registration and access for ...      S
# 10   Ability to create/configure extended, facilita...      S
# 11     Ability to set enrollment durations for courses      S
# 12   Ability to configure and enforce a certificati...      S
# 13   Ability to assign documents from a central doc...      S
# 14   Ability to offer closed discussion forums that...      S
# 15   Ability to associate multiple assessments with...      S
# 16   Ability to block access to course content unti...      S
# 17   Ability to associate an evaluation (survey) wi...      S
# 18   Ability for system to automatically issue cred...      S
# 19   Ability for users to self-report externally-ea...     SS
# 20   Ability to award users with a personalized PDF...      S
# 21   Ability to customize the look, feel, and navig...      S
# 22   Ability for user to search and browse the cont...      S
# 23   Ability to create tags and apply them to learn...     SS
# 24   Ability for visitors to the end user site to b...      S
# 25   Ability for the catalog to present and apply d...      S
# 26   Shopping cart/e-commerce capabilities that ena...      S
# 27   Ability for a user to access a course or other...      S
# 28   Ability to bulk import/register a list of user...      S
# 29   Ability to define groups, roles, and permissio...      S
# 30   Ability to provide distinctly branded/co-brand...      S
# 31   Ability for a designated administrator to mana...      S
# 32   Ability to configure and automate e-mail commu...      S
# 33   Configurable, automated confirmation e-mail se...      S
# 34   Configurable, automated reminder e-mail sent p...      S
# 35   Configurable, automated follow up e-mail sent ...      S
# 36   Ability to manually create and send e-mails to...      S
# 37   Ability to manually create and send e-mails on...      S
# 38           Ability to apply ADHA branding to e-mails      S
# ..                                                 ...    ...
# 102  Ability to publish an evaluation (survey) as a...      S
# 103  Ability to re-use a single evaluation (not cop...      S
# 104  Ability to easily insert graphics into an asse...      S
# 105  Ability to easily insert graphics into an asse...      S
# 106  Ability to apply branching or skip logic based...     SS
# 107  Ability to score test in real time and send en...      S
# 108  Ability to insert page breaks where desired in...      S
# 109  Ability to insert page breaks where desired in...      S
# 110  Item analysis to see how assessment (test) que...      S
# 111  Ability for end users to bookmark their place ...      S
# 112  Ability to provide closed captioning or third ...      S
# 113  Ability to deploy the system in multiple langu...      S
# 114  Ability to track where users are in a course, ...      S
# 115  Ability for an ADHA administrator to configure...      S
# 116  Ability to compare pre-test and post-test data...      S
# 117                 Phone-based support for ADHA staff      S
# 118                 E-mail based support for end users      S
# 119               Online knowledge base for ADHA staff      S
# 120                Online knowledge base for end users      S
# 121  Ability to sub-license the LMS to other groups...      S
# 122            Ability to host/support streaming media     SS
# 123  Ability to receive registration and enrollment...      S
# 124  Ability to support single sign-on with a Webin...      S
# 125  Ability to support deeper integration with Zoo...      S
# 126                Ability to support federated search      S
# 127              Ability to add custom database fields      S
# 128                   Separate app-based access to LMS      S
# 129  Ability to have external users (e.g., editoria...      S
# 130  Can the LMS host links to other LMS providers ...      S
# 131                                                NaN    NaN
#
#                                                   resp
# 9    We have experience with client preferred third...
# 10                                                 NaN
# 11   Course duration can be configured to a set num...
# 12                                                 NaN
# 13   The file manager acts as a repository for all ...
# 14   CourseStage discussion forums are full-feature...
# 15                                                 NaN
# 16   Requirements for issuance of credit are set at...
# 17                                                 NaN
# 18   Requirements for issuance of credit are set at...
# 19   The Self-Reported Learning module (included in...
# 20   A custom branded certificate is included as pa...
# 21                                                 NaN
# 22                                                 NaN
# 23   A number of dashboards are available with base...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27   Blocks can be added for comments to be added b...
# 28   Custom user profile fields can be added that a...
# 29                                                 NaN
# 30   Our Sub-portal Module allows client administra...
# 31                                                 NaN
# 32                                                 NaN
# 33   Along with finding out whether they answered c...
# 34   Any number and variety of CourseStage activiti...
# 35   The dashboard is highly configurable with chan...
# 36   Course shells can be given to the member compa...
# 37   Custom user profile fields can be added that a...
# 38   Done via course messaging (user sends request ...
# ..                                                 ...
# 102  Evaluations can exist within the context of a ...
# 103  Learning paths involving multiple courses/acti...
# 104  Graphics can be included as part of question t...
# 105  Graphics can be included as part of question t...
# 106  Using the add-on performance improvement modul...
# 107  The user’s activity logs – courses, activities...
# 108  Graphics can be included as part of question t...
# 109                                                NaN
# 110  CourseStage LMS has detailed item analysis rep...
# 111                                                NaN
# 112  Course duration can be configured to a set num...
# 113  Administrators can manually create and send em...
# 114  Full live logs are available in the LMS and ca...
# 115  A number of base reports enable administrators...
# 116  Our pre-post test reports is one of our strong...
# 117  Web Courseworks holds an annual virtual user g...
# 118  End-user training is going to be specific to e...
# 119  End-user training is going to be specific to e...
# 120  End-user training is going to be specific to e...
# 121                                                NaN
# 122  While CourseStage has the ability to host larg...
# 123  Questions can be categorized and tagged to fac...
# 124  We have experience with client preferred third...
# 125                                                NaN
# 126  We have experience with client preferred third...
# 127  Courses can be hidden, which will hide them fr...
# 128  An account manager is assigned to every Course...
# 129                                                NaN
# 130  Administrators have access to view, download, ...
# 131                                                NaN
#
# [123 rows x 3 columns]

# %%
difflib.SequenceMatcher(None, "The quick brown fox jumped over the lazy dog", "The quick brown fox jumped over the lazy dog").ratio()
# Out:
# 1.0

# %%
 # DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False)[source]

# newRFP.join(corpus, on = 'req', how = 'left' )

# newRFP.join(corpus.set_index(cols), on=cols)



# newRFP

newRFP.merge(corpus, how='left', left_on='req', right_on='req')
# Out:
#                                                  req rating_x resp_x rating_y  \
# 0  Ability to manage registration and access for ...      NaN    NaN      NaN
# 1  Ability to create/configure extended, facilita...      NaN    NaN      NaN
# 2    Ability to set enrollment durations for courses      NaN    NaN      NaN
# 3  Ability to configure and enforce a certificati...      NaN    NaN      NaN
#
#   resp_y
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
